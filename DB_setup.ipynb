-- %% [markdown]
-- ## create catalog

-- %%
create catalog if not exists ecommerce_dwh

-- %% [markdown]
-- ## Create Schema

-- %%
create schema if not exists ecommerce_dwh.staging;
create schema if not exists ecommerce_dwh.core;
create schema if not exists ecommerce_dwh.data_marts;
