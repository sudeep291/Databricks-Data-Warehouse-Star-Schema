# %% [markdown]
# ## transform the data

# %%
# %sql
select * from ecommerce_dwh.staging.sales_data_view

# %% [markdown]
# ## remove duplicates

# %%
# %sql
create or replace view ecommerce_dwh.core.sales_trm
as select distinct(*) from ecommerce_dwh.staging.sales_data_view
